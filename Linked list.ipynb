# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

# %%
class LinkedList:
    def __init__(self):
        self.head = None
        
    def insert_at_beginning(self,data):
        node = Node(data,self.head)
        self.head = node
        
    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data,None)
            return
        
        itr = self.head
        while(itr.next):
            itr = itr.next
        itr.next = Node(data,None)
        return
    
    def insert_values(self,data_list):
        #self.head = None
        for data in data_list:
            self.insert_at_end(data)
        
    def print(self):
        if(self.head is None):
            print("Linked list is empty")
        else:
            itr = self.head
            lst1 = ''
            while itr:
                lst1 = lst1 + str(itr.data) + '-->'
                itr = itr.next
            print(lst1)
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count = count+1
            itr = itr.next
        return count
                
    def insert_at(self,index,data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")
       
        if(index == 0):
            self.insert_at_beginning(data)
            return
        
        count = 0
        itr = self.head
        while itr:
            if(count==index-1):
                node = Node(data, itr.next)
                itr.next = node
                break
            itr = itr.next
            count = count + 1
            
    def insert_before(self,value,data):
        itr = self.head
        if(itr.data==value):
            self.insert_at_beginning(data)
            return
    
        while(itr):
            if(itr.data==value):
                node = Node(data,itr1.next)
                itr1.next = node
                break
            itr1 = itr
            itr = itr.next
        
    def insert_after(self,value,data):
        itr = self.head
        while(itr):
            if(itr.data==value):
                node = Node(data,itr.next)
                itr.next = node
                break
            itr = itr.next
            
    def remove_at(self,index):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")
        
        if(index==0):
            self.head = self.head.next
            return
        
        count = 0
        itr = self.head
        while itr:
            if(count == index-1):
                itr.next = itr.next.next
                break
            itr = itr.next
            count = count+1
            
    def remove_by_value(self,data):
        itr = self.head
        if(itr.data==data):
            self.head = itr.next
            return
        while(itr):
            if(itr.data == data):
                itr1.next = itr.next
                break
            itr1 = itr
            itr = itr.next
            
    def remove_before(self,data):
        itr = self.head
        if(itr.data == data):
            print("Already the first index, no element is present before it")
            return
        while(itr.next):
            if(itr.next.data == data):
                itr1.next = itr.next
                #itr.next = None
                break
            itr1 = itr
            itr = itr.next

    def remove_after(self,data):
        itr = self.head
        count = 1
        length = self.get_length()
        while(itr):
            if(itr.data == data):
                if(count == length):
                    print("Reached the last node, no value is present after it")
                    return
                if(count == length-1):
                    itr.next = None
                    return
                itr.next = itr.next.next
                itr.next.next = None
                break
            itr = itr.next
            count = count+1
        if(count > length):
            print("Value is not present")
            return

# %%
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_at_beginning(5)
    ll.insert_at_beginning(55)
    ll.insert_at_end(89)
    ll.print()
    ll.insert_values(['banana','mango','orange'])
    ll.print()
    ll.remove_at(3)
    ll.print()
    ll.insert_at(5,21)
    ll.print()
    ll.insert_at(0,"Papaya")
    ll.insert_before("banana","Jackfruit")
    ll.insert_after("mango","Pineapple")
    ll.print()
    ll.remove_by_value("mango")
    ll.print()
    ll.remove_before(89)
    ll.remove_after("orange")
    ll.print()
    print("Length of the linked list is:",ll.get_length())
# Out:
# 55-->5-->89-->
# 55-->5-->89-->banana-->mango-->orange-->
# 55-->5-->89-->mango-->orange-->
# 55-->5-->89-->mango-->orange-->21-->
# Papaya-->55-->5-->89-->mango-->Pineapple-->orange-->21-->
# Papaya-->55-->5-->89-->Pineapple-->orange-->21-->
# Papaya-->55-->89-->Pineapple-->orange-->
# Length of the linked list is: 5
